# %% [markdown]
# ### Problem Statement
# "Oil prices are difficult to forecast due to externalities, but our aim is to build the model which can help us to understand the pattern and make smart decision for customers and businesses."

# %% [markdown]
# ### EDA
# Exploratory data analysis is an approach to analyze the data using visualization and statistical techniques.

# %% [markdown]
# ### Steps in EDA
# - Describing the data
# - Data Cleaning
# - Data Manipulation
# - Data Analysis & Visualization

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the CSV file
oil = pd.read_csv('Oil.csv')

# %%
oil.head(10)
# Out:
#          Date  Price
# 0  1985-01-02  25.92
# 1  1985-01-03  25.84
# 2  1985-01-04  25.18
# 3  1985-01-07  25.56
# 4  1985-01-08  25.48
# 5  1985-01-09  25.43
# 6  1985-01-10  25.76
# 7  1985-01-11  25.77
# 8  1985-01-14  26.12
# 9  1985-01-15  25.91

# %%
oil.tail(10)
# Out:
#             Date  Price
# 9750  2023-05-10  72.56
# 9751  2023-05-11  70.87
# 9752  2023-05-12  70.04
# 9753  2023-05-15  71.11
# 9754  2023-05-16  70.86
# 9755  2023-05-17  72.83
# 9756  2023-05-18  71.86
# 9757  2023-05-19  71.55
# 9758  2023-05-22  71.99
# 9759  2023-05-23  72.91

# %%
oil.shape
# Out:
# (9760, 2)

# %%
oil.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9755    False
# 9756    False
# 9757    False
# 9758    False
# 9759    False
# Length: 9760, dtype: bool

# %%
oil.isnull().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9760 entries, 0 to 9759
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9760 non-null   object
#  1   Price   9760 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 152.6+ KB

# %%
# Finding the mean, variance, kurtosis & skewness

# %%
oil.mean()
# Out:
# Price    46.20002
# dtype: float64

# %%
oil.var()
# Out:
# Price    859.859034
# dtype: float64

# %%
oil.kurt()
# Out:
# Price   -0.566424
# dtype: float64

# %%
oil.skew()
# Out:
# Price    0.751496
# dtype: float64

# %%
# Convert 'Date' column to datetime
oil['Date'] = pd.to_datetime(oil['Date'])
oil.head()
# Out:
#         Date  Price
# 0 1985-01-02  25.92
# 1 1985-01-03  25.84
# 2 1985-01-04  25.18
# 3 1985-01-07  25.56
# 4 1985-01-08  25.48

# %%
# Exploratory Data Analysis (EDA)
print("Data Summary:")
print(oil.head())
print("\nData Statistics:")
print(oil.describe())
# Out:
# Data Summary:
#         Date  Price
# 0 1985-01-02  25.92
# 1 1985-01-03  25.84
# 2 1985-01-04  25.18
# 3 1985-01-07  25.56
# 4 1985-01-08  25.48
#
# Data Statistics:
#              Price
# count  9760.000000
# mean     46.200020
# std      29.323353
# min      10.010000
# 25%      20.210000
# 50%      35.715000
# 75%      67.705000
# max     145.290000

# %%
# Plotting the distribution of 'Price'
plt.figure(figsize=(20, 8))
sns.set_style('darkgrid')
sns.histplot(data=oil, x='Price', kde=True)
plt.title('Distribution of Price')
plt.show()

# %% [markdown]
# ### Outlier Detection

# %%
Q1 = oil.Price.quantile(0.25)
Q1
# Out:
# 20.21

# %%
Q3 = oil.Price.quantile(0.75) 
Q3
# Out:
# 67.705

# %%
IQR = Q3-Q1
IQR
# Out:
# 47.495

# %%
lower_cap= Q1-1.5*IQR
lower_cap
# Out:
# -51.03249999999999

# %%
upper_cap=Q3+1.5*IQR
upper_cap
# Out:
# 138.9475

# %%
oil[(oil.Price<lower_cap)|(oil.Price>upper_cap)]
# Out:
#            Date   Price
# 5889 2008-06-26  139.64
# 5890 2008-06-27  140.21
# 5891 2008-06-30  140.00
# 5892 2008-07-01  140.97
# 5893 2008-07-02  143.57
# 5894 2008-07-03  145.29
# 5895 2008-07-07  141.37
# 5898 2008-07-10  141.65
# 5899 2008-07-11  145.08
# 5900 2008-07-14  145.18

# %%
oil['Date']=pd.to_datetime(oil['Date'])

# %%
oil['year']=oil['Date'].dt.year
yearly_data = oil.groupby('year')

# %%
plt.figure(figsize=(18,10))
ax=sns.boxplot(x='year', y='Price', data=oil)
sns.set_style("whitegrid")
plt.xlabel("Year")
plt.ylabel("Price")
ax.set_title('Box Plot for Year-wise Outlier Detection',fontsize=25)
plt.show()

# %%
def cap_outliers(x):
    Q1=x.quantile(0.25)
    Q3=x.quantile(0.75)
    IQR=Q3-Q1
    upper_cap = Q3 + 1.5 * IQR 
    lower_cap = Q1 - 1.5 * IQR
    capped_values = np.clip(x, lower_cap, upper_cap)
    return capped_values

# %%
#capping Method to replace outliers
capped_data = yearly_data.apply(lambda x: cap_outliers(x['Price']))

# %%
oil['New_Price'] = capped_data.reset_index(level=0, drop=True)

# %%
oil.to_csv('cleaned_data.csv', index=False)

# %%
oil1 = pd.read_csv('cleaned_data.csv')

# %%
oil1.head(10)
# Out:
#          Date  Price  year  New_Price
# 0  1985-01-02  25.92  1985      25.92
# 1  1985-01-03  25.84  1985      25.84
# 2  1985-01-04  25.18  1985      25.18
# 3  1985-01-07  25.56  1985      25.56
# 4  1985-01-08  25.48  1985      25.48
# 5  1985-01-09  25.43  1985      25.43
# 6  1985-01-10  25.76  1985      25.76
# 7  1985-01-11  25.77  1985      25.77
# 8  1985-01-14  26.12  1985      26.12
# 9  1985-01-15  25.91  1985      25.91

# %%
plt.figure(figsize=(18,10))
ax=sns.boxplot(x='year', y='New_Price', data=oil1)
sns.set_style("whitegrid")
plt.xlabel("Year")
plt.ylabel("Price")
ax.set_title('Box Plot Year Wise',fontsize=30)
plt.show()

# %%
oil2 = oil1.drop(columns=['year','Price'],axis=1)

# %%
oil2
# Out:
#             Date  New_Price
# 0     1985-01-02      25.92
# 1     1985-01-03      25.84
# 2     1985-01-04      25.18
# 3     1985-01-07      25.56
# 4     1985-01-08      25.48
# ...          ...        ...
# 9755  2023-05-17      72.83
# 9756  2023-05-18      71.86
# 9757  2023-05-19      71.55
# 9758  2023-05-22      71.99
# 9759  2023-05-23      72.91
#
# [9760 rows x 2 columns]

# %%
oil2['Date'] = pd.to_datetime(oil2['Date'])
oil2.set_index('Date',inplace=True)

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(20, 8))
sns.set_style('darkgrid')
sns.lineplot(x='Date',y='New_Price',data=oil2)
plt.title('Oil Price Trend')
# Out:
# Text(0.5, 1.0, 'Oil Price Trend')

# %% [markdown]
# ### Time Series Decomposition

# %%
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.rcParams.update({'figure.figsize':(18,10), 'figure.dpi':75})
decomposition = sm.tsa.seasonal_decompose(oil2['New_Price'], period=120)
decomposition.plot()
plt.show()

# %% [markdown]
# ### Testing For Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# Null Hypothesis (H0):
# If accepted, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
#
# Alternate Hypothesis (H1):
# The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure. We interpret this result using the p-value from the test.
#
# p-value > 0.05: Accept the null hypothesis (H0), the data has a unit root and is non-stationary.
#
# p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.

# %%
test_result = adfuller(oil2['New_Price'])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(New_Price):
    result=adfuller(New_Price)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(oil2['New_Price'])
# Out:
# ADF Test Statistic : -2.2615959887342676
# p-value : 0.18465322975363563
# #Lags Used : 38
# Number of Observations Used : 9721
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
oil2['Price First Difference'] = oil2.diff()

# %%
oil2.head(10)
# Out:
#             New_Price  Price First Difference
# Date
# 1985-01-02      25.92                     NaN
# 1985-01-03      25.84                   -0.08
# 1985-01-04      25.18                   -0.66
# 1985-01-07      25.56                    0.38
# 1985-01-08      25.48                   -0.08
# 1985-01-09      25.43                   -0.05
# 1985-01-10      25.76                    0.33
# 1985-01-11      25.77                    0.01
# 1985-01-14      26.12                    0.35
# 1985-01-15      25.91                   -0.21

# %%
adfuller_test(oil2['Price First Difference'].dropna())
# Out:
# ADF Test Statistic : -13.505198610929316
# p-value : 2.9245895269466425e-25
# #Lags Used : 38
# Number of Observations Used : 9720
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
plt.plot(oil2['New_Price'],color='red',label='New_Price')
plt.plot(oil2['Price First Difference'])

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(oil2['New_Price'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig = plt.figure(figsize=(10,50))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(oil2['Price First Difference'].iloc[13:],lags=100,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(oil2['Price First Difference'].iloc[13:],lags=100,ax=ax2)

# %% [markdown]
# In this plot, the two dotted lines on either sides of 0 are the confidence interevals. These can be used to determine the ‘p’ and ‘q’ values as:
#
# p – The lag value where the PACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case p=4.
#
# q – The lag value where the ACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case q=4.

# %% [markdown]
# ## Model Generation

# %% [markdown]
# ### 1. Prophet

# %% [markdown]
# - The Prophet model is a time series forecasting model developed by Facebook's Core Data Science team. It is designed to provide accurate and intuitive forecasts for time series data, which includes observations collected sequentially over time.

# %%
#!pip install prophet

# %%
from prophet import Prophet
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly as py
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
oil3=oil1.copy()

# %%
oil3 = oil1.drop(columns=['year','Price'],axis=1)
oil3
# Out:
#             Date  New_Price
# 0     1985-01-02      25.92
# 1     1985-01-03      25.84
# 2     1985-01-04      25.18
# 3     1985-01-07      25.56
# 4     1985-01-08      25.48
# ...          ...        ...
# 9755  2023-05-17      72.83
# 9756  2023-05-18      71.86
# 9757  2023-05-19      71.55
# 9758  2023-05-22      71.99
# 9759  2023-05-23      72.91
#
# [9760 rows x 2 columns]

# %%
oil3.columns = ["ds","y"]

model = Prophet()
model.fit(oil3)
# Out:
# 16:23:00 - cmdstanpy - INFO - Chain [1] start processing
# 16:23:05 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods= 30, freq='d')

# %%
forecast = model.predict(future)
forecast.tail()
# Out:
#              ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 9785 2023-06-18  81.471521   70.268125   96.726740    81.471521    81.471521
# 9786 2023-06-19  81.486436   70.284601   95.095485    81.486436    81.486436
# 9787 2023-06-20  81.501351   69.550085   96.862933    81.501351    81.501351
# 9788 2023-06-21  81.516266   70.476706   96.246579    81.516266    81.516266
# 9789 2023-06-22  81.531181   70.295308   96.009271    81.531181    81.531181
#
#       additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 9785        2.766673              2.766673              2.766673  1.126438
# 9786        1.592178              1.592178              1.592178 -0.076628
# 9787        1.543107              1.543107              1.543107 -0.155523
# 9788        1.607506              1.607506              1.607506 -0.121700
# 9789        1.683365              1.683365              1.683365 -0.076643
#
#       weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 9785      1.126438      1.126438  1.640235      1.640235      1.640235
# 9786     -0.076628     -0.076628  1.668806      1.668806      1.668806
# 9787     -0.155523     -0.155523  1.698629      1.698629      1.698629
# 9788     -0.121700     -0.121700  1.729206      1.729206      1.729206
# 9789     -0.076643     -0.076643  1.760009      1.760009      1.760009
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 9785                   0.0                         0.0
# 9786                   0.0                         0.0
# 9787                   0.0                         0.0
# 9788                   0.0                         0.0
# 9789                   0.0                         0.0
#
#       multiplicative_terms_upper       yhat
# 9785                         0.0  84.238194
# 9786                         0.0  83.078614
# 9787                         0.0  83.044458
# 9788                         0.0  83.123772
# 9789                         0.0  83.214547

# %%
forecast[["ds","yhat","yhat_lower","yhat_upper"]].head()
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 1985-01-02  24.800363   10.794022   38.428398
# 1 1985-01-03  24.807110   11.757196   37.549788
# 2 1985-01-04  24.753715   11.381171   38.594970
# 3 1985-01-07  24.635985   11.648028   37.502939
# 4 1985-01-08  24.513028   11.664614   38.229875

# %%
model.plot(forecast);
plt.title(" Oil Price Forecast ")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# calculate MAE between expected and predicted values for next 60 mont
y_true = oil3['y'].values
y_pred = forecast['yhat'][:-30].values
mae = mean_absolute_error(y_true, y_pred)
print('MAE: %.2f' % mae)
r = r2_score(y_true, y_pred)
print('R-squared Score: %.2f' % r)
rmse = mean_squared_error(y_true, y_pred)
print('RMSE: %.2f' % rmse)
# Out:
# MAE: 6.46
# R-squared Score: 0.88
# RMSE: 105.12

# %%
plt.figure(figsize=(20,8))
# plot expected vs actual
plt.plot(y_true, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title("Crude Oil Production")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # 2.LSTM

# %% [markdown]
# - The Long Short-Term Memory (LSTM) Model for Time Series Forecasting used to to forecast time series data.
# - The LSTM cell adds long-term memory in an even more performant way because it allows even more parameters to be learned.

# %%
from tensorflow import keras
from tensorflow.keras.layers import Bidirectional, Dropout, Activation, Dense, LSTM
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras.models import Sequential
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
oil4 = oil1.copy()

# %%
oil4 = oil1.drop(columns=['year','Price'],axis=1)

# %%
scaler = MinMaxScaler()
# fit the format of the scaler -> convert shape from (1000, ) -> (1000, 1)
price = oil4.New_Price.values.reshape(-1, 1)
scaled = scaler.fit_transform(price)

seq_len = 60

def split_into_sequences(data, seq_len):
    n_seq = len(data) - seq_len + 1
    return np.array([data[i:(i+seq_len)] for i in range(n_seq)])

def get_train_test_sets(data, seq_len, train_frac):
    sequences = split_into_sequences(data, seq_len)
    n_train = int(sequences.shape[0] * train_frac)
    x_train = sequences[:n_train, :-1, :]
    y_train = sequences[:n_train, -1, :]
    x_test = sequences[n_train:, :-1, :]
    y_test = sequences[n_train:, -1, :]
    return x_train, y_train, y_test, y_test

x_train, y_train, x_test, y_test = get_train_test_sets(scaled, seq_len, train_frac=0.8)

# %%
# fraction of the input to drop; helps prevent overfitting
dropout = 0.2
window_size = seq_len - 1

# build a 3-layer LSTM RNN
model = keras.Sequential()

model.add(LSTM(window_size, return_sequences=True, input_shape=(window_size, x_train.shape[-1])))
model.add(Dropout(rate=dropout))
# Bidirectional allows for training of sequence data forwards and backwards
model.add(Bidirectional(LSTM((window_size * 2), return_sequences=True))) 
model.add(Dropout(rate=dropout))
model.add(Bidirectional(LSTM(window_size, return_sequences=False))) 
model.add(Dense(units=1))
# linear activation function: activation is proportional to the input
model.add(Activation('linear'))

model.compile(loss='mean_squared_error',optimizer='adam')
history = model.fit(x_train,y_train,epochs=10,batch_size=32,shuffle=False,validation_split=0.2)
# Out:
# Epoch 1/10
# 194/194 [==============================] - 36s 160ms/step - loss: 0.0038 - val_loss: 0.0860
# Epoch 2/10
# 194/194 [==============================] - 31s 159ms/step - loss: 0.0020 - val_loss: 0.0677
# Epoch 3/10
# 194/194 [==============================] - 29s 150ms/step - loss: 0.0047 - val_loss: 0.0699
# Epoch 4/10
# 194/194 [==============================] - 30s 152ms/step - loss: 0.0079 - val_loss: 0.0508
# Epoch 5/10
# 194/194 [==============================] - 27s 141ms/step - loss: 0.0063 - val_loss: 0.0547
# Epoch 6/10
# 194/194 [==============================] - 25s 129ms/step - loss: 0.0053 - val_loss: 0.0510
# Epoch 7/10
# 194/194 [==============================] - 27s 141ms/step - loss: 0.0059 - val_loss: 0.0526
# Epoch 8/10
# 194/194 [==============================] - 27s 140ms/step - loss: 0.0058 - val_loss: 0.0385
# Epoch 9/10
# 194/194 [==============================] - 26s 136ms/step - loss: 0.0058 - val_loss: 0.0227
# Epoch 10/10
# 194/194 [==============================] - 70s 364ms/step - loss: 0.0053 - val_loss: 0.0076

# %%
y_pred = model.predict(x_test)

# invert the scaler to get the absolute price data
y_test_orig = scaler.inverse_transform(y_test)
y_pred_orig = scaler.inverse_transform(y_pred)

# plots of prediction against actual data
plt.plot(y_test_orig, label='Actual Price', color='orange')
plt.plot(y_pred_orig, label='Predicted Price', color='green')
 
plt.title('Oil Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.show();
# Out:
# 61/61 [==============================] - 0s 4ms/step

# %%
mae = mean_absolute_error(y_test_orig, y_pred_orig)
print('MAE: %.2f' % mae)
r = r2_score(y_test_orig, y_pred_orig)
print('R-squared Score: %.2f' % r)
rmse = mean_squared_error(y_test_orig, y_pred_orig)
print('RMSE: %.2f' % rmse)
# Out:
# MAE: 15.20
# R-squared Score: -0.22
# RMSE: 420.51

# %% [markdown]
# # 3. ARIMA

# %% [markdown]
# - The Auto Regressive Integrated Moving Average (ARIMA) model is among one of the more popular and widely used statistical methods for time-series forecasting.
# - It is a class of statistical algorithms that captures the standard temporal dependencies that is unique to a time series data.

# %%
oil4 = oil1.copy()
oil4
# Out:
#             Date  Price  year  New_Price
# 0     1985-01-02  25.92  1985      25.92
# 1     1985-01-03  25.84  1985      25.84
# 2     1985-01-04  25.18  1985      25.18
# 3     1985-01-07  25.56  1985      25.56
# 4     1985-01-08  25.48  1985      25.48
# ...          ...    ...   ...        ...
# 9755  2023-05-17  72.83  2023      72.83
# 9756  2023-05-18  71.86  2023      71.86
# 9757  2023-05-19  71.55  2023      71.55
# 9758  2023-05-22  71.99  2023      71.99
# 9759  2023-05-23  72.91  2023      72.91
#
# [9760 rows x 4 columns]

# %%
oil4 = oil1.drop(columns=['year','Price'],axis=1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
arima = ARIMA(oil4['New_Price'], order=(3,1,2)).fit()
predictions = arima.predict()

# %%
plt.figure(figsize=(16,4))
plt.plot(oil4.New_Price, label="Actual",  color='red')
plt.plot(predictions, label="Predicted",  color='purple')
plt.title('Oil Price Prediction', fontsize=20)
plt.ylabel('Price', fontsize=16)
plt.legend()

# %%
mae = mean_absolute_error(oil4.New_Price, predictions)
print('MAE: %.2f' % mae)
r = r2_score(oil4.New_Price, predictions)
print('R-squared Score: %.2f' % r)
rmse = mean_squared_error(oil4.New_Price, predictions)
print('RMSE: %.2f' % rmse)
# Out:
# MAE: 0.74
# R-squared Score: 1.00
# RMSE: 1.55
